# %% [markdown]
# <a href="https://colab.research.google.com/github/Arthi1234583/Data-science-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = np.random.randn(1000)
plt.figure(figsize=(7, 5))
plt.hist(data, bins=30, color='green', edgecolor='black', alpha=0.7)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e53382fefede> in <cell line: 0>()
#       1 categories = ['A', 'B', 'C', 'D']
#       2 values = [10, 25, 15, 30]
# ----> 3 plt.figure(figsize=(6, 4))
#       4 plt.bar(categories, values, color='purple')
#       5 plt.xlabel("Categories")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
plt.figure(figsize=(7, 5))
plt.hist(data, bins=30, color='green', edgecolor='black', alpha=0.7)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()
